# %% [markdown]
# <a href="https://colab.research.google.com/github/11daniel/AIPND-2022/blob/main/3rd_session_python_with_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Conditional Statements

# %%
name = " Python "
if name == "java":
  print("if")
elif name.lower().strip() == "python":
  print("elif")
else:
  print("else")
# Out:
# elif

# %%
# given a string e.g, + 45 or - 51 find out the sign of the number
number = "-57.01"

# %%
converted_number = int(float(number))

if converted_number > 0:
  print('+ve')
else:
  print('-ve')
# Out:
# -ve

# %%
subscription_status = False
country = "USA"

# %%
subscription_status = True
country = "CAN"

# %%
subscription_status = False
country = "IND"

# %%
(country != "USA" and country == "CAN")
# Out:
# False

# %%
(country != "USA" or country == "CAN")

# %%
if (not subscription_status) and (country != "USA" or country == "CAN"):
  print("Valid subscriber")
else:
  print("Invalid subscriber")
# Out:
# Valid subscriber

# %% [markdown]
# Check whether the triangle is equilateral, scalene, or isosceles:
# - Equilateral, when all three sides are equal
# - isosceles, if any 2 sides are equal
# - else, scalene

# %%
# test case equilateral
side_a = 20
side_b = 20
side_c = 20

# %%
# test case isosceles
side_a = 30
side_b = 20
side_c = 20

# %%
# test case isosceles
side_a = 30
side_b = 30
side_c = 20

# %%
# test case isosceles
side_a = 30
side_b = 20
side_c = 30

# %%
# test case scalene
side_a = 30
side_b = 20
side_c = 10

# %%
# TODO write if- else algorithm

# %% [markdown]
# ## Loops

# %%
# Write a program to print the below string pattern till n terms

# 2 , 22, 222, 2222, ..... n terms

# %%
def print_n_pattern(n : int, input_num :int = 2):
  if n < 1:
    return "invalid pattern n should be greater than 1"
    # raise Exception("n should be greater than 1")

  # result = ""
  return str(input_num) * n
  # for i in range(n):
  #   result = result + str(input_num)
  #   print(result)

  # return result

# %%
result = print_n_pattern(2, 2)
print("The result is {}".format(result))
# Out:
# The result is 22

# %% [markdown]
# ## Function

# %% [markdown]
# #### Write a code to print pyramid
# #### *
# #### **
# #### ***
# #### ****
# #### *****
#
# #### Hint 1: use  print('*',end='')

# %%
def print_star(layer_count: int):
  pass

# %%
print_star(1)

# %% [markdown]
# #### Write a code to print pyramid numbers
# #### 1
# #### 2 3
# #### 4 5 6
